# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Görsel Ayarları
sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 150
plt.rcParams["font.family"] = "serif"

# Dosya Yolları
BASELINE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline/baseline_metrics.csv"
SMOTE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote/baseline_smote_metrics.csv"

print("📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...")

if os.path.exists(BASELINE_PATH) and os.path.exists(SMOTE_PATH):
    # 1. Verileri Oku
    df_base = pd.read_csv(BASELINE_PATH)
    df_smote = pd.read_csv(SMOTE_PATH)
    
    # 2. Etiketleme (Hangi deney olduğunu belirtelim)
    df_base["Experiment"] = "Baseline (Ham Veri)"
    df_smote["Experiment"] = "SMOTE (Dengelenmiş)"
    
    # 3. İsim Temizliği
    # SMOTE tablosunda isimler "SVM_SMOTE" gibi, onları "SVM" yapalım ki eşleşsin
    df_smote["model"] = df_smote["model"].str.replace("_SMOTE", "")
    
    # 4. Tabloları Birleştir (Alt alta ekle)
    df_compare = pd.concat([df_base, df_smote], ignore_index=True)
    
    # 5. Sıralama (Baseline F1 skoruna göre sıralayalım)
    # Önce modelleri baseline skoruna göre sıralı bir liste yapalım
    order = df_base.sort_values(by="f1_macro", ascending=False)["model"].tolist()
    
    # 6. Çizim
    plt.figure(figsize=(14, 7))
    
    # Bar Plot (hue='Experiment' sayesinde yan yana çizer)
    ax = sns.barplot(
        data=df_compare,
        x="model",
        y="f1_macro",
        hue="Experiment",
        order=order, # Sıralamayı uygula
        palette=["#34495e", "#2ecc71"] # Koyu Mavi (Baseline) vs Yeşil (SMOTE)
    )
    
    # Başlık ve Eksenler
    plt.title("Veri Dengeleme Etkisi: Baseline vs SMOTE (F1-Score Macro)", fontsize=16, fontweight='bold')
    plt.xlabel("Model", fontsize=12)
    plt.ylabel("F1 Score (Macro)", fontsize=12)
    plt.ylim(0, 1.15) # Üstte boşluk bırak
    plt.legend(title="Deney Grubu", loc="upper right")
    
    # 7. Değerleri Yazdırma
    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", padding=3, fontsize=9, fontweight='bold')

    plt.tight_layout()
    
    # Kaydet
    save_path = "../results/figures/comparison_baseline_vs_smote_f1_macro.png"
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()
    
    print(f"✅ Karşılaştırma grafiği kaydedildi: {save_path}")

else:
    print("❌ Dosyalar bulunamadı! Lütfen önce run_baseline.py ve run_baseline_smote.py çalıştırın.")
# Out:
# 📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...
# ✅ Karşılaştırma grafiği kaydedildi: ../results/figures/comparison_baseline_vs_smote_f1_macro.png

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Görsel Ayarları
sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 150
plt.rcParams["font.family"] = "serif"

# Dosya Yolları
BASELINE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline/baseline_metrics.csv"
SMOTE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote/baseline_smote_metrics.csv"

print("📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...")

if os.path.exists(BASELINE_PATH) and os.path.exists(SMOTE_PATH):
    # 1. Verileri Oku
    df_base = pd.read_csv(BASELINE_PATH)
    df_smote = pd.read_csv(SMOTE_PATH)
    
    # 2. Etiketleme (Hangi deney olduğunu belirtelim)
    df_base["Experiment"] = "Baseline (Ham Veri)"
    df_smote["Experiment"] = "SMOTE (Dengelenmiş)"
    
    # 3. İsim Temizliği
    # SMOTE tablosunda isimler "SVM_SMOTE" gibi, onları "SVM" yapalım ki eşleşsin
    df_smote["model"] = df_smote["model"].str.replace("_SMOTE", "")
    
    # 4. Tabloları Birleştir (Alt alta ekle)
    df_compare = pd.concat([df_base, df_smote], ignore_index=True)
    
    # 5. Sıralama (Baseline F1 skoruna göre sıralayalım)
    # Önce modelleri baseline skoruna göre sıralı bir liste yapalım
    order = df_base.sort_values(by="accuracy", ascending=False)["model"].tolist()
    
    # 6. Çizim
    plt.figure(figsize=(14, 7))
    
    # Bar Plot (hue='Experiment' sayesinde yan yana çizer)
    ax = sns.barplot(
        data=df_compare,
        x="model",
        y="accuracy",
        hue="Experiment",
        order=order, # Sıralamayı uygula
        palette=["#34495e", "#2ecc71"] # Koyu Mavi (Baseline) vs Yeşil (SMOTE)
    )
    
    # Başlık ve Eksenler
    plt.title("Veri Dengeleme Etkisi: Baseline vs SMOTE (Accuracy)", fontsize=16, fontweight='bold')
    plt.xlabel("Model", fontsize=12)
    plt.ylabel("Accuracy", fontsize=12)
    plt.ylim(0, 1.15) # Üstte boşluk bırak
    plt.legend(title="Deney Grubu", loc="upper right")
    
    # 7. Değerleri Yazdırma
    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", padding=3, fontsize=9, fontweight='bold')

    plt.tight_layout()
    
    # Kaydet
    save_path = "../results/figures/comparison_baseline_vs_smote_accuracy.png"
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()
    
    print(f"✅ Karşılaştırma grafiği kaydedildi: {save_path}")

else:
    print("❌ Dosyalar bulunamadı! Lütfen önce run_baseline.py ve run_baseline_smote.py çalıştırın.")
# Out:
# 📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...
# ✅ Karşılaştırma grafiği kaydedildi: ../results/figures/comparison_baseline_vs_smote_accuracy.png

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Görsel Ayarları
sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 150
plt.rcParams["font.family"] = "serif"

# Dosya Yolları
BASELINE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline/baseline_metrics.csv"
SMOTE_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote/baseline_smote_metrics.csv"

print("📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...")

if os.path.exists(BASELINE_PATH) and os.path.exists(SMOTE_PATH):
    # 1. Verileri Oku
    df_base = pd.read_csv(BASELINE_PATH)
    df_smote = pd.read_csv(SMOTE_PATH)
    
    # 2. Etiketleme (Hangi deney olduğunu belirtelim)
    df_base["Experiment"] = "Baseline (Ham Veri)"
    df_smote["Experiment"] = "SMOTE (Dengelenmiş)"
    
    # 3. İsim Temizliği
    # SMOTE tablosunda isimler "SVM_SMOTE" gibi, onları "SVM" yapalım ki eşleşsin
    df_smote["model"] = df_smote["model"].str.replace("_SMOTE", "")
    
    # 4. Tabloları Birleştir (Alt alta ekle)
    df_compare = pd.concat([df_base, df_smote], ignore_index=True)
    
    # 5. Sıralama (Baseline F1 skoruna göre sıralayalım)
    # Önce modelleri baseline skoruna göre sıralı bir liste yapalım
    order = df_base.sort_values(by="recall_weighted", ascending=False)["model"].tolist()
    
    # 6. Çizim
    plt.figure(figsize=(14, 7))
    
    # Bar Plot (hue='Experiment' sayesinde yan yana çizer)
    ax = sns.barplot(
        data=df_compare,
        x="model",
        y="recall_weighted",
        hue="Experiment",
        order=order, # Sıralamayı uygula
        palette=["#34495e", "#2ecc71"] # Koyu Mavi (Baseline) vs Yeşil (SMOTE)
    )
    
    # Başlık ve Eksenler
    plt.title("Veri Dengeleme Etkisi: Baseline vs SMOTE (Recall Weighted)", fontsize=16, fontweight='bold')
    plt.xlabel("Model", fontsize=12)
    plt.ylabel("Recall (Weighted)", fontsize=12)
    plt.ylim(0, 1.15) # Üstte boşluk bırak
    plt.legend(title="Deney Grubu", loc="upper right")
    
    # 7. Değerleri Yazdırma
    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", padding=3, fontsize=9, fontweight='bold')

    plt.tight_layout()
    
    # Kaydet
    save_path = "../results/figures/comparison_baseline_vs_smote_recall_weighted.png"
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()
    
    print(f"✅ Karşılaştırma grafiği kaydedildi: {save_path}")

else:
    print("❌ Dosyalar bulunamadı! Lütfen önce run_baseline.py ve run_baseline_smote.py çalıştırın.")
# Out:
# 📊 Baseline vs SMOTE Karşılaştırması Hazırlanıyor...
# ✅ Karşılaştırma grafiği kaydedildi: ../results/figures/comparison_baseline_vs_smote_recall_weighted.png

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
import sys
import os

# Proje yolunu ekle
sys.path.append(os.path.abspath(os.path.join('..')))
from src.data_loader import load_raw_data
from src.preprocessing import split_features_target, build_preprocessor

# Ayarlar
sns.set(style="whitegrid")
plt.figure(figsize=(12, 5))

# 1. Orijinal Veri
df = load_raw_data("/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/data/raw-data/Sleep_health_and_lifestyle_dataset.csv")
X, y = split_features_target(df)
original_counts = y.value_counts()

plt.subplot(1, 2, 1)
sns.barplot(x=original_counts.index, y=original_counts.values, palette="Reds")
plt.title("Orijinal Veri Dağılımı (Dengesiz)", fontsize=12, fontweight='bold')
plt.xlabel("Sınıflar")
plt.ylabel("Kişi Sayısı")
plt.bar_label(plt.gca().containers[0]) # type: ignore

# 2. SMOTE Sonrası Veri
# Hızlıca SMOTE uygulayalım (Görsel için)
le = LabelEncoder()
y_enc = le.fit_transform(y)
preprocessor = build_preprocessor(X)
X_trans = preprocessor.fit_transform(X)

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_trans, y_enc) # type: ignore
res_counts = pd.Series(y_res).value_counts() # type: ignore
res_counts.index = le.classes_ # İsimleri geri getir

plt.subplot(1, 2, 2)
sns.barplot(x=res_counts.index, y=res_counts.values, palette="Greens")
plt.title("SMOTE Sonrası Dağılım (Dengeli)", fontsize=12, fontweight='bold')
plt.xlabel("Sınıflar")
plt.ylabel("Kişi Sayısı")
plt.bar_label(plt.gca().containers[0]) # type: ignore

plt.tight_layout()
plt.savefig("/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/figures/data_balance_comparison.png")
plt.show()
print("✅ Veri dağılım görseli kaydedildi.")
# Out:
# /var/folders/06/61zr6n0n0rs4fbl42p7szkfm0000gn/T/ipykernel_40981/2246627613.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=original_counts.index, y=original_counts.values, palette="Reds")
# /var/folders/06/61zr6n0n0rs4fbl42p7szkfm0000gn/T/ipykernel_40981/2246627613.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=res_counts.index, y=res_counts.values, palette="Greens")
# ✅ Veri dağılım görseli kaydedildi.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

# Görsel Ayarları
sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 150
plt.rcParams["font.family"] = "serif"

# Dosya Yolları (Senin bilgisayarındaki yollar)
BASE_DIR = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline"
FILTER_DIR = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-filtered"
SMOTE_DIR = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote"

# Dosya İsimleri (Eğer klasör isimlerin farklıysa burayı kontrol et)
FILES = {
    "Baseline": os.path.join(BASE_DIR, "baseline_metrics.csv"),
    "SMOTE": os.path.join(SMOTE_DIR, "baseline_smote_metrics.csv"),
    "Filtreli": os.path.join(FILTER_DIR, "filtered_metrics_all.csv")
}

print("📊 Proje Evrimi Grafikleri (Model İsimleriyle) Hazırlanıyor...")

best_models = []

# 1. Her Dosyadan En İyi Modeli Çek
for stage_name, file_path in FILES.items():
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        
        # En yüksek F1-Macro skoruna sahip modeli bul
        best_row = df.sort_values(by="f1_macro", ascending=False).iloc[0]
        
        # --- MODEL VE FİLTRE İSMİNİ AYIKLAMA ---
        # Model adını bul (bazı dosyalarda 'model', bazılarında 'base_model' yazar)
        raw_model_name = best_row['model'] if 'model' in best_row else best_row['base_model']
        
        # Gereksiz ekleri temizle
        clean_model_name = raw_model_name.replace("_SMOTE", "").replace("_none", "").replace("_wavelet", "")
        
        # Filtre var mı kontrol et (Sadece filtered dosyasında vardır)
        filter_suffix = ""
        if "filter_method" in best_row:
            filter_method = str(best_row["filter_method"])
            if filter_method.lower() != "none":
                filter_suffix = f" + {filter_method.capitalize()}" # Örn: + Wavelet
            else:
                filter_suffix = " (Raw)" # Filtre yoksa Raw yazalım
        
        # Sonuç İsim: "SVM" veya "RF + Wavelet"
        display_name = f"{clean_model_name}{filter_suffix}"
        
        # Grafikte görünecek tam etiket: "Filtreli [RF + Wavelet]"
        full_label = f"{stage_name}\n[{display_name}]"
        
        # Verileri topla
        metrics = {
            "Aşama": full_label, # Hue (Renk) olarak bunu kullanacağız
            "Model": clean_model_name,
            "Accuracy": best_row.get("accuracy", 0),
            "F1 Score (Macro)": best_row.get("f1_macro", 0),
            "Precision (Macro)": best_row.get("precision_macro", 0),
            "Recall (Macro)": best_row.get("recall_macro", 0),
            "Specificity": best_row.get("specificity_macro", 0),
            "AUC": best_row.get("roc_auc_ovr_macro", 0)
        }
        best_models.append(metrics)
    else:
        print(f"⚠️ Uyarı: {file_path} bulunamadı. Lütfen dosya yolunu kontrol edin.")

if best_models:
    df_evolution = pd.DataFrame(best_models)
    
    # Veriyi "Long Format"a çevir
    df_melted = df_evolution.melt(
        id_vars=["Aşama", "Model"], 
        var_name="Metrik", 
        value_name="Skor"
    )

    # --- GÖRSEL 1: GRUPLU BAR GRAFİĞİ ---
    plt.figure(figsize=(14, 7))
    
    chart = sns.barplot(
        data=df_melted,
        x="Metrik",
        y="Skor",
        hue="Aşama", # Artık burada model ismi de yazacak
        palette=["#95a5a6", "#3498db", "#2ecc71"] # Gri -> Mavi -> Yeşil
    )
    
    plt.title("Proje Gelişim Süreci: Şampiyon Modeller ve Performansları", fontsize=16, fontweight='bold')
    plt.ylim(0.5, 1.02) 
    plt.legend(title="Aşama [Kazanan Model]", loc="lower right", frameon=True)
    plt.ylabel("Skor (0-1 Arası)")
    plt.xlabel("")
    
    for container in chart.containers:
        chart.bar_label(container, fmt="%.3f", padding=3, fontsize=9, fontweight='bold')

    plt.tight_layout()
    save_path_1 = "../results/figures/evolution_all_metrics_named.png"
    plt.savefig(save_path_1)
    plt.show()
    print(f"✅ Evrim grafiği kaydedildi: {save_path_1}")
    
    # --- GÖRSEL 2: DETAYLI HEATMAP ---
    plt.figure(figsize=(12, 5))
    
    # Pivot tablo yap (Index artık model ismini de içeriyor)
    heatmap_data = df_evolution.set_index("Aşama").drop(columns=["Model"])
    
    sns.heatmap(
        heatmap_data,
        annot=True,
        fmt=".3f",
        cmap="Blues",
        linewidths=1,
        cbar=False,
        annot_kws={"size": 13, "weight": "bold"}
    )
    
    plt.title("Şampiyon Modellerin Detaylı Skor Karşılaştırması", fontsize=15, fontweight='bold')
    plt.yticks(rotation=0) # Satır isimlerini düz yap
    plt.tight_layout()
    
    save_path_2 = "../results/figures/evolution_heatmap_named.png"
    plt.savefig(save_path_2)
    plt.show()
    print(f"✅ Detay tablosu kaydedildi: {save_path_2}")

    print("\n--- KAZANANLAR LİSTESİ ---")
    print(df_evolution[["Aşama", "F1 Score (Macro)"]])

else:
    print("❌ Hiçbir veri dosyası okunamadı. Yolları kontrol et!")
# Out:
# 📊 Proje Evrimi Grafikleri (Model İsimleriyle) Hazırlanıyor...
# ✅ Evrim grafiği kaydedildi: ../results/figures/evolution_all_metrics_named.png
# ✅ Detay tablosu kaydedildi: ../results/figures/evolution_heatmap_named.png
#
# --- KAZANANLAR LİSTESİ ---
#                   Aşama  F1 Score (Macro)
# 0       Baseline\n[SVM]          0.956583
# 1          SMOTE\n[SVM]          0.943788
# 2  Filtreli\n[RF (Raw)]          0.956944

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import math

# Görsel Ayarları
sns.set(style="white")
plt.rcParams["figure.dpi"] = 150
plt.rcParams["font.family"] = "serif"

# --- DOSYA YOLLARI ---
# SMOTE sonuçlarının olduğu klasör (run_baseline_smote.py buraya kaydetmişti)
# Eğer klasör ismini değiştirdiysen burayı güncelle!
METRICS_PATH = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote/baseline_smote_metrics.csv"
TABLES_DIR = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/tables-baseline-smote" 

print("📊 SMOTE Modellerinin Hata Matrisleri Çiziliyor...")

if os.path.exists(METRICS_PATH):
    # 1. Metrikleri Oku
    df_metrics = pd.read_csv(METRICS_PATH)
    # Accuracy skoruna göre sıralayalım ki en iyiler başta çıksın.
    df_sorted = df_metrics.sort_values(by = "accuracy", ascending = False)
    models = df_sorted["model"].tolist()

    print(f"Toplam {len(models)} model bulundu: {models}")



    # 2. Grid Ayarları
    num_plots = len(models)
    n_cols = 3
    n_rows = math.ceil(num_plots / n_cols)
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
    axes = axes.flatten() 
    
    cmap = "Blues" # SMOTE için Mavi tonu (Güveni/İstikrarı simgelesin)

    for i, model_name in enumerate(models):
        score = df_sorted.loc[df_sorted['model'] == model_name, 'f1_macro'].values[0]
        
        # Dosya adını oluştur: confusion_matrix_SVM_SMOTE.csv
        cm_filename = f"confusion_matrix_{model_name}.csv"
        cm_path = os.path.join(TABLES_DIR, cm_filename)
        
        ax = axes[i]
        
        if os.path.exists(cm_path):
            cm_df = pd.read_csv(cm_path, index_col=0)
            
            sns.heatmap(
                cm_df, 
                annot=True, 
                fmt="d", 
                cmap=cmap, 
                cbar=False, 
                ax=ax, 
                linewidths=1, 
                linecolor='lightgray',
                annot_kws={"size": 14, "weight": "bold"}
            )
            
            # Başlığı temizle (SVM_SMOTE -> SVM + SMOTE)
            clean_name = model_name.replace("_SMOTE", " + SMOTE")
            ax.set_title(f"{clean_name}\n(F1: {score:.3f})", fontweight='bold', size=12, pad=10)
            ax.set_xlabel(""); ax.set_ylabel("")
            
        else:
            ax.text(0.5, 0.5, "Dosya Yok", ha='center', va='center', color='red')
            ax.set_title(model_name)

    # Boş kalan grafikleri temizle
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    # Ortak Eksen İsimleri
    fig.text(0.5, 0.02, 'Tahmin Edilen (Predicted)', ha='center', fontsize=14, fontweight='bold')
    fig.text(0.02, 0.5, 'Gerçek Etiket (True)', va='center', rotation='vertical', fontsize=14, fontweight='bold')

    plt.subplots_adjust(hspace=0.4, wspace=0.3)
    plt.tight_layout(rect=[0.05, 0.05, 1, 1])
    
    save_path = "/Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/figures/confusion_matrices_smote.png"
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()
    
    print(f"✅ SMOTE görselleri kaydedildi: {save_path}")

else:
    print(f"❌ Dosya bulunamadı: {METRICS_PATH}")
# Out:
# 📊 SMOTE Modellerinin Hata Matrisleri Çiziliyor...
# Toplam 10 model bulundu: ['SVM_SMOTE', 'LR_SMOTE', 'VCLF_SMOTE', 'MLP_SMOTE', 'CNN_SMOTE', 'XGB_SMOTE', 'RF_SMOTE', 'DT_SMOTE', 'LSTM_SMOTE', 'GNB_SMOTE']
# ✅ SMOTE görselleri kaydedildi: /Users/melih/Desktop/sleep-project/sleep-disorder-signal-processing/results/figures/confusion_matrices_smote.png
